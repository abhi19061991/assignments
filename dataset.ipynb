# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi19061991/assignments/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/practise/DATA.xlsx")

# %%
df
# Out:
#     field_name field_type                          field_description  \
# 0   MRTINTCODE    SC2 011                      ACTUAL INTEREST RATES
# 1     MRTGROUP    SC2 025              FIXED OR CONTRACTUAL INTEREST
# 2  MCVINTEREST    SC4 012                      FIXED AND CONTRACTUAL
# 3       MGCOPT    SC1 107  VALUES WAITING TO BE DECLARED AND APPLIED
#
#   GROUP_IDENTIFICATION
# 0              000-099
# 1              100-199
# 2              200-299
# 3              300-399

# %%
mrtintcode = "MRTINTCODE"
result = '-'.join([mrtintcode[i:i+3] for i in range(0, len(mrtintcode), 3)])
print(result)
# Out:
# MRT-INT-COD-E

# %%
df['field_name']=df['field_name'].apply(lambda x:result)

# %%
df
# Out:
#       field_name field_type                          field_description  \
# 0  MRT-INT-COD-E    SC2 011                      ACTUAL INTEREST RATES
# 1  MRT-INT-COD-E    SC2 025              FIXED OR CONTRACTUAL INTEREST
# 2  MRT-INT-COD-E    SC4 012                      FIXED AND CONTRACTUAL
# 3  MRT-INT-COD-E    SC1 107  VALUES WAITING TO BE DECLARED AND APPLIED
#
#   GROUP_IDENTIFICATION
# 0              000-099
# 1              100-199
# 2              200-299
# 3              300-399

# %%
df['field_type']=df['field_type'].replace('SC2 011','x2')

# %%
df['field_type']=df['field_type'].replace('SC2 025','s9(3)')

# %%
df['field_type']=df['field_type'].replace('SC4 012','s9(2)v9(2)')

# %%
df['field_type']=df['field_type'].replace('SC1 107','X(1')

# %%
df
# Out:
#       field_name  field_type                          field_description  \
# 0  MRT-INT-COD-E          x2                      ACTUAL INTEREST RATES
# 1  MRT-INT-COD-E       s9(3)              FIXED OR CONTRACTUAL INTEREST
# 2  MRT-INT-COD-E  s9(2)v9(2)                      FIXED AND CONTRACTUAL
# 3  MRT-INT-COD-E         X(1  VALUES WAITING TO BE DECLARED AND APPLIED
#
#   GROUP_IDENTIFICATION
# 0              000-099
# 1              100-199
# 2              200-299
# 3              300-399

# %%
numbers={'000-099':1,'100-199':2,'200-299':3,'300-399':4}

# %%
df['GROUP_IDENTIFICATION']=df['GROUP_IDENTIFICATION'].map(numbers)

# %%
df
# Out:
#       field_name  field_type                          field_description  \
# 0  MRT-INT-COD-E          x2                      ACTUAL INTEREST RATES
# 1  MRT-INT-COD-E       s9(3)              FIXED OR CONTRACTUAL INTEREST
# 2  MRT-INT-COD-E  s9(2)v9(2)                      FIXED AND CONTRACTUAL
# 3  MRT-INT-COD-E         X(1  VALUES WAITING TO BE DECLARED AND APPLIED
#
#    GROUP_IDENTIFICATION
# 0                     1
# 1                     2
# 2                     3
# 3                     4
